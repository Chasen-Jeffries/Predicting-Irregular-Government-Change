# %% [markdown]
# # Final-Cleaning-Economic-Avg-Data
# This file will create the avgs data for the economic dataset

# %%
# Importing Packages
import pandas as pd
import numpy as np

# %%
# Loading in Dataset
Economic_Data = pd.read_csv('Data/Clean/Combined/Economic-Data.csv')
Economic_Data.head()
# Out:
#        Country  Year         GDPPC  GDP_Growth  GINI  Gov_Debt  Inflation  \
# 0  Afghanistan  1960           NaN         NaN   NaN       NaN        NaN
# 1      Albania  1960           NaN         NaN   NaN       NaN        NaN
# 2    Argentina  1960   7410.305029         NaN   NaN       NaN        NaN
# 3    Australia  1960  19904.943410         NaN   NaN       NaN   3.728814
# 4      Austria  1960  12051.151170         NaN   NaN       NaN   1.945749
#
#     Life_Exp  Unemployment   Edu    PI
# 0  32.535000           NaN  0.37     0
# 1  54.439000           NaN  2.98     0
# 2  63.978000           NaN  5.67  6375
# 3  70.817073           NaN  8.53   312
# 4  68.585610           NaN  5.86   562

# %%
# Change to a DataFrame
df_01 = pd.DataFrame(Economic_Data)

# Check Data types
df_01.dtypes
# Out:
# Country          object
# Year              int64
# GDPPC           float64
# GDP_Growth      float64
# GINI            float64
# Gov_Debt        float64
# Inflation       float64
# Life_Exp        float64
# Unemployment    float64
# Edu             float64
# PI               object
# dtype: object

# %%
# Change PI to numeric
df_01['PI'] = pd.to_numeric(df_01['PI'], errors='coerce')

# Double Checking Data types 
df_01.dtypes
# Out:
# Country          object
# Year              int64
# GDPPC           float64
# GDP_Growth      float64
# GINI            float64
# Gov_Debt        float64
# Inflation       float64
# Life_Exp        float64
# Unemployment    float64
# Edu             float64
# PI              float64
# dtype: object

# %%
# Filter the DataFrame for years
df_01 = df_01[(df_01['Year'] >= 1975)]

# Checking data
df_01.head()
# Out:
#                   Country  Year          GDPPC  GDP_Growth  GINI  Gov_Debt  \
# 265           Afghanistan  1975            NaN         NaN   NaN       NaN
# 266               Albania  1975            NaN         NaN   NaN       NaN
# 267  United Arab Emirates  1975  105688.087100         NaN   NaN       NaN
# 268             Argentina  1975    9935.938635   -0.028412   NaN       NaN
# 269             Australia  1975   28257.955510    1.336443   NaN       NaN
#
#      Inflation   Life_Exp  Unemployment    Edu      PI
# 265        NaN  40.100000           NaN   0.92     0.0
# 266        NaN  68.328000           NaN   5.35     0.0
# 267        NaN  65.080000           NaN   2.99     0.0
# 268        NaN  67.081000           NaN   6.85  8937.0
# 269  15.162455  72.625366           NaN  10.52   500.0

# %%
# Define the starting year for intervals
start_year = 1975

# Calculate the interval group
df_01['Interval_Group'] = ((df_01['Year'] - start_year) // 5) * 5 + start_year

# Group by 'ID' and 'Interval_Group', then calculate the mean
df_01 = df_01.groupby(['Country', 'Interval_Group']).mean(numeric_only=True)

# Checking data
df_01.head()
# Out:
#                               Year  GDPPC  GDP_Growth  GINI  Gov_Debt  \
# Country     Interval_Group
# Afghanistan 1975            1975.0    NaN         NaN   NaN       NaN
#             1980            1980.0    NaN         NaN   NaN       NaN
#             1985            1985.0    NaN         NaN   NaN       NaN
#             1990            1990.0    NaN         NaN   NaN       NaN
#             1995            1995.0    NaN         NaN   NaN       NaN
#
#                             Inflation  Life_Exp  Unemployment   Edu      PI
# Country     Interval_Group
# Afghanistan 1975                  NaN    40.100           NaN  0.92     0.0
#             1980                  NaN    39.618           NaN  1.22  4562.0
#             1985                  NaN    33.550           NaN  1.57  3125.0
#             1990                  NaN    45.967           NaN  1.87  5250.0
#             1995                  NaN    52.544          8.26  2.26  5250.0

# %%
# Reset the index  
df_01 = df_01.reset_index()

# %%
# Drop the 'Year' column
df_01 = df_01.drop('Year', axis=1)

# %%
# Rename the 'Interval_Group' column to 'Year'
df_01 = df_01.rename(columns={'Interval_Group': 'Year'})

# Checking data
df_01.head()
# Out:
#        Country  Year  GDPPC  GDP_Growth  GINI  Gov_Debt  Inflation  Life_Exp  \
# 0  Afghanistan  1975    NaN         NaN   NaN       NaN        NaN    40.100
# 1  Afghanistan  1980    NaN         NaN   NaN       NaN        NaN    39.618
# 2  Afghanistan  1985    NaN         NaN   NaN       NaN        NaN    33.550
# 3  Afghanistan  1990    NaN         NaN   NaN       NaN        NaN    45.967
# 4  Afghanistan  1995    NaN         NaN   NaN       NaN        NaN    52.544
#
#    Unemployment   Edu      PI
# 0           NaN  0.92     0.0
# 1           NaN  1.22  4562.0
# 2           NaN  1.57  3125.0
# 3           NaN  1.87  5250.0
# 4          8.26  2.26  5250.0

# %% [markdown]
# # Lag Data 1 Year

# %%
def lag_data(df, lag, key_columns=['Year', 'Country','PI']):
    # Make a copy of the DataFrame to avoid modifying the original
    df_copy = df.copy()

    # Ensure the key columns are set as the index
    df_copy.set_index(key_columns, inplace=True)
    
    # Identify columns to lag (all columns except the key columns)
    columns_to_lag = [col for col in df_copy.columns if col not in key_columns]
    
    # Apply lag, ensuring it's done within each group defined by 'Country' in the index
    # This assumes 'Country' is one of the key columns and thus part of the multi-level index
    for column in columns_to_lag:
        df_copy[column] = df_copy.groupby(level='Country')[column].shift(lag)
    
    # Reset the index to return to the original structure
    df_reset = df_copy.reset_index()

    return df_reset

# %%
data = pd.DataFrame(df_01)
df = data 
lag_amount = 1
df_Avg_01 = lag_data(df, lag_amount)
df_Avg_01.head()
# Out:
#    Year      Country      PI  GDPPC  GDP_Growth  GINI  Gov_Debt  Inflation  \
# 0  1975  Afghanistan     0.0    NaN         NaN   NaN       NaN        NaN
# 1  1980  Afghanistan  4562.0    NaN         NaN   NaN       NaN        NaN
# 2  1985  Afghanistan  3125.0    NaN         NaN   NaN       NaN        NaN
# 3  1990  Afghanistan  5250.0    NaN         NaN   NaN       NaN        NaN
# 4  1995  Afghanistan  5250.0    NaN         NaN   NaN       NaN        NaN
#
#    Life_Exp  Unemployment   Edu
# 0       NaN           NaN   NaN
# 1    40.100           NaN  0.92
# 2    39.618           NaN  1.22
# 3    33.550           NaN  1.57
# 4    45.967           NaN  1.87

# %%
# Filter the DataFrame for years 1990 to 2020 without using the index
df_Avg_01 = df_Avg_01[(df_Avg_01['Year'] >= 2000) & (df_Avg_01['Year'] <= 2020)]

df_Avg_01.dropna()

# Checking Data
df_Avg_01.head()
# df_Avg_01.tail()
# len(df_Avg_01)
# Out:
# 349

# %%
# Exporting DF Lag 1 Year
df_Avg_01.to_csv('Data/Clean/Final/Economic-Avg-01.csv', index = False)

# %%
data = pd.DataFrame(df_01)
df = data 
lag_amount = 2
df_Avg_02 = lag_data(df, lag_amount)
df_Avg_02.head()

# %%
# Filter the DataFrame for years 2000 to 2020 without using the index
df_Avg_02 = df_Avg_02[(df_Avg_02['Year'] >= 2000) & (df_Avg_02['Year'] <= 2020)]
df_Avg_02.head()

# %%
# Exporting DF Lag 5 Year
df_Avg_02.to_csv('Data/Clean/Final/Political-Avg-02.csv', index = False)
