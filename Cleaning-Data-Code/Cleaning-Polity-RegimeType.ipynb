# %%
import pandas as pd

# %%
df = pd.read_csv('Data/Original/Political/Polity-RegimeType.csv')

# %%
df.head()
# Out:
#    p5    cyear  ccode scode      country  year  flag  fragment  democ  autoc  \
# 0   0  7001800    700   AFG  Afghanistan  1800     0       NaN      1      7
# 1   0  7001801    700   AFG  Afghanistan  1801     0       NaN      1      7
# 2   0  7001802    700   AFG  Afghanistan  1802     0       NaN      1      7
# 3   0  7001803    700   AFG  Afghanistan  1803     0       NaN      1      7
# 4   0  7001804    700   AFG  Afghanistan  1804     0       NaN      1      7
#
#    ...  interim  bmonth  bday   byear  bprec  post  change   d5  sf  regtrans
# 0  ...      NaN     1.0   1.0  1800.0    1.0  -6.0    88.0  1.0 NaN       NaN
# 1  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN       NaN
# 2  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN       NaN
# 3  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN       NaN
# 4  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN       NaN
#
# [5 rows x 37 columns]

# %%
columns_to_keep = ['country', 'year', 'polity']

# %%
column_names = ['Country', 'Year', 'Gov']

# %%
data = df[columns_to_keep]
data.head()
# Out:
#        country  year  polity
# 0  Afghanistan  1800      -6
# 1  Afghanistan  1801      -6
# 2  Afghanistan  1802      -6
# 3  Afghanistan  1803      -6
# 4  Afghanistan  1804      -6

# %%
data.columns = column_names
data.head()
# Out:
#        Country  Year  Gov
# 0  Afghanistan  1800   -6
# 1  Afghanistan  1801   -6
# 2  Afghanistan  1802   -6
# 3  Afghanistan  1803   -6
# 4  Afghanistan  1804   -6

# %%
data.to_csv('Data/Clean/Political/Regime-Type.csv', index = False)
