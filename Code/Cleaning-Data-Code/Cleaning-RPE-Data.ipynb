# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/Original/Political/RPE.csv')

# %%
df.head()
# Out:
#    cowcode  trccode  imfcode  uncode ISO3      country  year   ape1  ape1n  \
# 0      700      111      512       4  AFG  Afghanistan  1960  0.113  0.084
# 1      700      111      512       4  AFG  Afghanistan  1961  0.120  0.098
# 2      700      111      512       4  AFG  Afghanistan  1962  0.119  0.093
# 3      700      111      512       4  AFG  Afghanistan  1963  0.122  0.095
# 4      700      111      512       4  AFG  Afghanistan  1964  0.141  0.108
#
#    rpe_agri  rpe_gdp  rpe_gdp_nonres  rpr_work  rpr_eap  rpa_full  rpa_sub
# 0     1.380    0.715           0.795       NaN      NaN       NaN      NaN
# 1     1.378    0.718           0.795     0.590    0.614       NaN      NaN
# 2     1.399    0.732           0.808     0.619    0.604       NaN      NaN
# 3     1.397    0.742           0.816     0.604    0.607       NaN      NaN
# 4     1.467    0.782           0.858     0.618    0.619       NaN      NaN

# %%
Columns_to_keep = ['country','year','rpe_gdp']

# %%
# Select only these columns
data = df[Columns_to_keep]

# %%
Column_names = ['Country','Year','RPE']

# %%
data.columns = Column_names
data.head()
# Out:
#        Country  Year    RPE
# 0  Afghanistan  1960  0.715
# 1  Afghanistan  1961  0.718
# 2  Afghanistan  1962  0.732
# 3  Afghanistan  1963  0.742
# 4  Afghanistan  1964  0.782

# %%
data.to_csv('Data/Clean/Political/RPE.csv', index = False)
